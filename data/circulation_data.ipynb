# %% [markdown]
# # Python testing code

# %%
import sys
import pandas as pd
# sys.path.append('path/to/library-pipeline/src')
# from data_procesing.ingestion import load_csv

df = pd.read_csv('circulation_data.csv')
print(df.head())
print(df.info())
# Out:
#   transaction_id member_id               isbn checkout_date return_date  \
# 0      TXN000000    M93810  978-0-433-21819-7    2024-08-17  2024-08-25
# 1      TXN000001    M28289  978-0-338-90838-4    2024-08-15  2024-09-02
# 2      TXN000002    M21395  978-1-02-654235-4    2023-12-27         NaN
# 3      TXN000003    M38657  978-0-559-40781-9    2025-09-24         NaN
# 4      TXN000004    M36062  978-0-8495-9310-9    2025-02-08  2025-02-16
#
#   branch_id
# 0     BR012
# 1     BR011
# 2     BR001
# 3     BR010
# 4     BR012
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5100 entries, 0 to 5099
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  5100 non-null   object
#  1   member_id       4998 non-null   object
#  2   isbn            4848 non-null   object
#  3   checkout_date   5100 non-null   object
#  4   return_date     4614 non-null   object
# ...
